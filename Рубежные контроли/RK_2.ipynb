# %% [markdown]
# ## Рубежный контроль №2 по курсу Методов Машинного Обучения
# #### Выполнил: студент группы ИУ5-25М Мацнев Александр Андреевич, вариант 13

# %% [markdown]
# ### Задача 1
# ##### Условие: Для одного из алгоритмов временных различий, реализованных Вами в соответствующей лабораторная работе: SARSA, Q-обучение, Двойное Q-обучение осуществите подбор гиперпараметров. Критерием оптимизации должна являться суммарная награда.

# %% [markdown]
# В лабораторной работа 5 изучались алгоритмы машинного обучения. В качестве среды моделирования был использован пакет gymnasium, из него использовались среды CliffWalking-v0 и Taxi-v3.

# %% [markdown]
# ### Cliff Walking

# %% [markdown]
# Для каждого из трёх алгоритмов были подобраны оптимальные гиперпараметры:

# %% [markdown]
# Для алгоритма SARSA: eps=0.4, lr=0.1, gamma=0.98, num_episodes=250

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# После обучения можно увидеть, что суммарная награда за эпизод установилась на значении около -150, в некоторых эпизодах доходя до 0. Обучение при этом заняло менее секунды.

# %% [markdown]
# Для алгоритма Q-learning: eps=0.4, lr=0.05, gamma=0.98, num_episodes=600

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# После обучения можно увидеть, что суммарная награда за эпизод установилась на значении около -250, в некоторых эпизодах доходя до 0. Обучение при этом заняло около секунды.

# %% [markdown]
# Для алгоритма Double Q-Learning: eps=0.4, lr=0.1, gamma=0.98, num_episodes=350

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# После обучения можно увидеть, что суммарная награда за эпизод установилась на значении около -250, в некоторых эпизодах доходя до 0. Обучение при этом заняло около секунды.

# %% [markdown]
# ### Taxi

# %% [markdown]
# Для алгоритма SARSA: eps=0.4, lr=0.4, gamma=0.98, num_episodes=2200

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# После обучения можно увидеть, что суммарная награда за эпизод установилась на значении около -50. Обучение при этом заняло около 6 секунд.

# %% [markdown]
# Для алгоритма Q-Learning: eps=0.4, lr=0.3, gamma=0.98, num_episodes=1200

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# После обучения можно увидеть, что суммарная награда за эпизод установилась на значении около -30. Обучение при этом заняло около 7 секунд.

# %% [markdown]
# Для алгоритма Double Q-Learning: eps=0.4, lr=0.3, gamma=0.98, num_episodes=1500

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# После обучения можно увидеть, что суммарная награда за эпизод установилась на значении около -30. Обучение при этом заняло около 7 секунд.
